# %% [markdown]
# Importing the dataset

# %%
import gdown
import matplotlib.pyplot as plt

# %%
url = 'https://drive.google.com/uc?id=1O7m1010EJjLE5QxLZiM9Fpjs7Oj6e684'

# %%
gdown.download(url, 'data.zip', quiet=True)
# Out:
# 'data.zip'

# %% [markdown]
# Unzipping the data

# %%
from zipfile import ZipFile

# %%
with ZipFile('data.zip', 'r')as z:
  z.extractall('data')

# %%
from tensorflow.keras.preprocessing.image import image_dataset_from_directory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-7fae7ea40691> in <cell line: 1>()
# ----> 1 from tensorflow.keras.preprocessing.image import image_dataset_from_directory
#
# ImportError: cannot import name 'image_dataset_from_directory' from 'tensorflow.keras.preprocessing.image' (/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/preprocessing/image/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data = image_dataset_from_directory('/content/data')
# Out:
# Found 202599 files belonging to 1 classes.

# %%
type(data)
# Out:
# tensorflow.python.data.ops.prefetch_op._PrefetchDataset

# %%
data.get_next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b1f5bf64a53e> in <cell line: 1>()
# ----> 1 data.get_next()
#
# AttributeError: '_PrefetchDataset' object has no attribute 'get_next'

# %%
for x in data:
  plt.imshow(x[0][0].astype('int32'))
  break

# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# Creating the generator

# %%
def create_generator():
  generator = Sequential()
