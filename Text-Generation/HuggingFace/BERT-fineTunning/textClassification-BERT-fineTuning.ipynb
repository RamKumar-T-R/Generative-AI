# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GEN_AI-Intern/Text-Generation/HuggingFace/BERT-fineTunning/review1100_categorized.csv')

# %%
dataset['Category'].value_counts()
# Out:
# Course Content        1066
# Instructor Quality      71
# Platform Usability      10
# Name: Category, dtype: int64

# %%
# !pip install transformers --quiet

# %%
# !pip install transformers[touch] --quiet
# Out:
# WARNING: transformers 4.35.2 does not provide the extra 'touch'

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (1147, 4)

# %%
dataset
# Out:
#         Id                                             Review  Label  \
# 0        0                               good and interesting      5
# 1        1  This class is very helpful to me. Currently, I...      5
# 2        2  like!Prof and TAs are helpful and the discussi...      5
# 3        3  Easy to follow and includes a lot basic and im...      5
# 4        4  Really nice teacher!I could got the point eazl...      4
# ...    ...                                                ...    ...
# 1142  1142  itÂ´s very interesting course ,it gives you al...      5
# 1143  1143  An amazing course! I have found many interesti...      5
# 1144  1144  It's just plain excellent. Great content and p...      5
# 1145  1145  A very interesting course and I'm at the begin...      5
# 1146  1146  Outstanding course, delivered measuredly, conc...      5
#
#                 Category
# 0         Course Content
# 1         Course Content
# 2     Instructor Quality
# 3         Course Content
# ...

# %%
from transformers import BertTokenizer
token = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
input_data = token(list(dataset['Review']), max_length=512, truncation=True, padding=True, )
input_data
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
y = dataset['Category']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install datasets
from datasets import Dataset

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
train_data = Dataset.from_dict({'input_ids': input_data['input_ids'], 'labels':y})

# %%
from transformers import BertForSequenceClassification, Trainer, TrainingArguments

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels = 3)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install accelerate>=0.20.1

# %%
# !pip install transformers[torch]

# %%
training_args = TrainingArguments(
    output_dir = './results',
    num_train_epochs= 10,
    logging_dir = './logs'
)

# %%
#import os
#os._exit(00)

# %%
trainer = Trainer(model = model, args=training_args, train_dataset=train_data)

# %%
train_data.shape
# Out:
# (1147, 2)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1440' max='1440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1440/1440 19:00, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.315200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.291900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1440, training_loss=0.2871990468766954, metrics={'train_runtime': 1141.6399, 'train_samples_per_second': 10.047, 'train_steps_per_second': 1.261, 'total_flos': 3017910901340160.0, 'train_loss': 0.2871990468766954, 'epoch': 10.0})

# %%
x_test = []
y_test = []

for i in np.random.randint(0, data.shape[0], 5):
  x_test.append(dataset['Review'][i])
  y_test.append(dataset['Category'][i])

# %%
test_data = Dataset.from_dict({'input_ids': token(x_test, truncation=True, padding=True, max_length=512)['input_ids']})

# %%
pred = trainer.predict(test_data)

# %%
class_name = encoder.classes_.tolist()
class_name

# %%
for i in range(5):
  print(y_test[i])
  p = np.argmax(pred[0][i])
  print(p)
  print(class_name[p])
