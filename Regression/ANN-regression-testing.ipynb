# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('/content/ann-reg.h5')

# %%
test = [[10.29, 39.40, 1005.2, 74.25]]

# %%
model.predict(test)
# Out:
# 1/1 [==============================] - 0s 191ms/step
# array([[470.8178]], dtype=float32)
